# %% [markdown]
# ### Ejercicio: Analizar texto
#
# ● Utilizar un texto de proyecto Gutenberg en castellano
# http://www.gutenberg.org/browse/languages/es
#
# ● Contar palabras y ordenar por frecuencia:
#
#         ● Limpiar preludio y licencia de Project Gutenberg
#         ● Omitir “palabras vacías” (stop words) y símbolos
#
# ● Encontrar personajes
#
# ● Hacer un análisis extra a gusto

# %% [markdown]
# El Texto a analizar será el libro **Agua de nieve** de Concha Espina

# %%
import textacy
from collections import Counter
from spacy.lang.en.stop_words import STOP_WORDS
from textacy.doc import Doc

# %%
#Obtenemos el texto del libro
with open("datasets/agua_de_nieve.txt", "r") as t:
    texto = t.read()

# %% [markdown]
# ### Contar palabras y ordenar por frecuencia

# %%
#Limpiamos preludio y licencia de Project Gutenberg (además tambien decidimos limpiar todo el prologo inicial del libro
#que no aporta a la informacion que estamos buscando extraer)

#removemos la cabecera
texto = texto[2803:]#texto[6984:]
texto[:30]
# Out:
# 'LIBRO PRIMERO\n\nLA VIAJERA RUBI'

# %%
#removemos toda la informacion al final del libro que no es parte de la historia
texto = texto[:-23612]
texto[-50:]
# Out:
# ', como la voz mansa y pura del agua de la nieve...'

# %% [markdown]
# Para poder utilizar el modelo de español de spacy es necesario descargarlo. Para esto ejecutar en la consola la siguiente linea:
#
# **spacy install es_core_news_sm**

# %%
# Cargamos el modelo para el idioma español y parseamos el texto para obtener un "bag-of-terms" en doc
nlp = textacy.load_spacy('es_core_news_sm', disable=('parser',))
proc_text = nlp(texto)
type(proc_text)
# Out:
# spacy.tokens.doc.Doc

# %%
proc_text[:100]
# Out:
# LIBRO PRIMERO
#
# LA VIAJERA RUBIA
#
#
#
#
# I
#
# EN EL LAZARETO DE SAN SIMÓN.--REGINA DE ALCÁNTARA.--EL ESPEJO
# TURBIO.--LOS MISTERIOS DE UNA NOCHE DE MAYO.--LA FELICIDAD DESCALZA.
#
#
# TOCÓ el bote dulcemente en la tierra, tierra frondosa y húmeda que
# emergía de las aguas como un jirón de los blandos vergeles submarinos.
# Regina de Alcántara, moza elegante y gentilísima, de ojos negros y
# cabellos rubios, desembarcó de un salto, rápida y leve, sin advertir que
# un pasajero le tendía

# %%
stop = list(STOP_WORDS)
def clean_doc(doc):
    #Limpiamos puntuacion, simbolos y stopwords del texto y convertimos los token a minuscula
    print("Cleaning")
    # limpiamos puntuacion simbolos y stopwords
    doc = [tok.text for tok in doc if (tok.text not in stop and tok.pos_ != "PUNCT" and tok.pos_ != "SYM")]
    # convertimos a minuscula
    doc = [tok.lower() for tok in doc]
    doc = ' '.join(doc)
    print("Doc cleaned")
    return nlp(doc)

# %%
clean_text = clean_doc(proc_text) # type spacy.tokens.doc.Doc
doc = Doc(clean_text) # type textacy.doc.Doc --> for using the method 'to_bag_of_words'
# Out:
# Cleaning
# Doc cleaned

# %%
bow_doc = doc.to_bag_of_words(as_strings=True);

# %%
#Palabras ordenadas por frecuencia de mayor a menor
words_counts = Counter(bow_doc)
sorted(words_counts.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('y', 3333),
#  ('á', 1417),
#  ('comer', 429),
#  ('regina', 413),
#  ('parir', 330),
#  ('ojo', 170),
#  ('entrar', 168),
#  ('sobrar', 164),
#  ('querer', 161),
#  ('mujer', 148),
#  ('amor', 147),
#  ('mozo', 141),
#  ('corazón', 139),
#  ('niño', 134),
#  ('mirar', 132),
#  ('madre', 129),
#  ('don', 116),
#  ('sentir', 115),
#  ('vida', 110),
#  ('voz', 109),
#  ('casar', 104),
#  ('triste', 103),
#  ('mar', 100),
#  ('muchacho', 96),
#  ('bajar', 95),
#  ('parecer', 94),
#  ('do', 93),
#  ('carlos', 90),
#  ('carlota', 89),
#  ('hijo', 89),
#  ('joven', 83),
#  ('llegar', 82),
#  ('dama', 82),
#  ('maría', 80),
#  ('señor', 79),
#  ('eugenia', 78),
#  ('manuel', 78),
#  ('adolfo', 77),
#  ('ó', 77),
#  ('dolor', 77),
#  ('ana', 77),
#  ('alma', 74),
#  ('dulce', 73),
#  ('luz', 73),
#  ('buscar', 73),
#  ('mundo', 73),
#  ('ramírez', 72),
#  ('velasquín', 72),
#  ('volver', 71),
#  ('alcántara', 70),
#  ('preguntar', 69),
#  ('padre', 68),
#  ('coser', 67),
#  ('sombrar', 66),
#  ('cielo', 66),
#  ('flor', 65),
#  ('dejar', 64),
#  ('fué', 64),
#  ('pasar', 62),
#  ('tierra', 61),
#  ('asir', 61),
#  ('velasco', 60),
#  ('hombre', 60),
#  ('noche', 59),
#  ('caer', 58),
#  ('palabra', 58),
#  ('sonreír', 57),
#  ('quedar', 57),
#  ('labio', 56),
#  ('hora', 55),
#  ('llorar', 55),
#  ('rubio', 53),
#  ('viajero', 53),
#  ('--no', 53),
#  ('abrir', 53),
#  ('cabeza', 53),
#  ('año', 52),
#  ('torremar', 52),
#  ('caminar', 52),
#  ('morir', 51),
#  ('novio', 51),
#  ('pensar', 51),
#  ('amar', 51),
#  ('huir', 50),
#  ('señorito', 50),
#  ('creer', 49),
#  ('subir', 49),
#  ('daniel', 49),
#  ('salir', 48),
#  ('sonrisa', 48),
#  ('nadar', 48),
#  ('vivir', 47),
#  ('oír', 47),
#  ('grande', 46),
#  ('aguar', 46),
#  ('tardar', 46),
#  ('pobre', 45),
#  ('sol', 45),
#  ('lágrima', 45),
#  ('hallar', 45),
#  ('venir', 45),
#  ('memoria', 45),
#  ('murmurar', 45),
#  ('llamar', 45),
#  ('contar', 45),
#  ('brazo', 44),
#  ('recordar', 44),
#  ('aire', 44),
#  ('robledo', 44),
#  ('a', 43),
#  ('responder', 43),
#  ('bello', 43),
#  ('detener', 43),
#  ('dios', 43),
#  ('jaime', 42),
#  ('mano', 41),
#  ('seguir', 41),
#  ('tratar', 41),
#  ('frente', 41),
#  ('vestir', 41),
#  ('felicidad', 41),
#  ('blanco', 41),
#  ('loco', 40),
#  ('actitud', 40),
#  ('punto', 40),
#  ('escuchar', 40),
#  ('sentimiento', 39),
#  ('amigo', 39),
#  ('olvidar', 39),
#  ('alto', 38),
#  ('nombrar', 38),
#  ('hermano', 38),
#  ('feliz', 38),
#  ('hermoso', 38),
#  ('dudar', 38),
#  ('obscuro', 38),
#  ('correr', 38),
#  ('pálido', 38),
#  ('pie', 38),
#  ('bosque', 37),
#  ('ternura', 37),
#  ('rostro', 37),
#  ('manir', 37),
#  ('fuerte', 36),
#  ('esperar', 36),
#  ('fondo', 36),
#  ('enamorar', 36),
#  ('esperanzar', 36),
#  ('hablar', 36),
#  ('abandonar', 36),
#  ('espíritu', 36),
#  ('inquietud', 35),
#  ('sufrir', 35),
#  ('merced', 35),
#  ('reinar', 35),
#  ('ofrecer', 35),
#  ('instante', 35),
#  ('juventud', 35),
#  ('penar', 34),
#  ('historia', 34),
#  ('formar', 34),
#  ('hogar', 34),
#  ('tomar', 34),
#  ('semblante', 33),
#  ('caballero', 33),
#  ('curiosidad', 33),
#  ('doctor', 33),
#  ('temblar', 33),
#  ('negro', 33),
#  ('soñar', 33),
#  ('raro', 33),
#  ('alzar', 32),
#  ('marta', 32),
#  ('familia', 32),
#  ('amigar', 32),
#  ('confuso', 32),
#  ('costa', 32),
#  ('placer', 32),
#  ('velar', 32),
#  ('gozar', 32),
#  ('suponer', 32),
#  ('pablar', 32),
#  ('profundo', 32),
#  ('paso', 32),
#  ('padecer', 31),
#  ('cruel', 31),
#  ('tristeza', 31),
#  ('tornar', 31),
#  ('alegrar', 31),
#  ('muerte', 31),
#  ('imagen', 31),
#  ('caro', 30),
#  ('noble', 30),
#  ('gentil', 30),
#  ('secretar', 30),
#  ('repetir', 30),
#  ('unir', 30),
#  ('seguro', 30),
#  ('levantar', 30),
#  ('infantil', 29),
#  ('nevar', 29),
#  ('cruzar', 29),
#  ('frase', 29),
#  ('horizonte', 29),
#  ('poblar', 29),
#  ('sacudir', 28),
#  ('encontrar', 28),
#  ('soler', 28),
#  ('silenciar', 28),
#  ('íntimo', 28),
#  ('piadoso', 28),
#  ('reír', 28),
#  ('callar', 28),
#  ('curioso', 28),
#  ('--sí', 28),
#  ('trazar', 27),
#  ('suspirar', 27),
#  ('hermanar', 27),
#  ('miedo', 27),
#  ('besar', 27),
#  ('viudo', 27),
#  ('deber', 27),
#  ('largar', 26),
#  ('emoción', 26),
#  ('lograr', 26),
#  ('médico', 26),
#  ('nube', 26),
#  ('librar', 26),
#  ('ilusionar', 26),
#  ('caricia', 26),
#  ('paisaje', 26),
#  ('silencioso', 26),
#  ('rosa', 26),
#  ('ola', 26),
#  ('acento', 26),
#  ('acaso', 25),
#  ('pasión', 25),
#  ('piedad', 25),
#  ('sorprender', 25),
#  ('cantar', 25),
#  ('mañana', 25),
#  ('talar', 25),
#  ('ciudad', 25),
#  ('lanzar', 25),
#  ('andar', 25),
#  ('misterio', 24),
#  ('ardiente', 24),
#  ('existencia', 24),
#  ('contemplar', 24),
#  ('terrible', 24),
#  ('tragedia', 24),
#  ('apenar', 24),
#  ('lleno', 24),
#  ('balandro', 24),
#  ('vió', 24),
#  ('viejo', 24),
#  ('expresión', 24),
#  ('luchar', 24),
#  ('sorpresa', 23),
#  ('ideo', 23),
#  ('dormir', 23),
#  ('misterioso', 23),
#  ('mostrar', 23),
#  ('agudo', 23),
#  ('asombrar', 23),
#  ('saludar', 23),
#  ('esposo', 23),
#  ('cruz', 23),
#  ('boda', 23),
#  ('gritar', 23),
#  ('poeta', 23),
#  ('hermosura', 22),
#  ('pensamiento', 22),
#  ('dulzura', 22),
#  ('viento', 22),
#  ('celso', 22),
#  ('selva', 22),
#  ('advertir', 22),
#  ('pechar', 22),
#  ('juan', 22),
#  ('clavar', 22),
#  ('drama', 22),
#  ('bordar', 22),
#  ('romper', 22),
#  ('tender', 22),
#  ('eco', 22),
#  ('gravar', 22),
#  ('recuerdo', 22),
#  ('terror', 22),
#  ('doler', 22),
#  ('asomar', 22),
#  ('balcón', 22),
#  ('helar', 22),
#  ('cariño', 21),
#  ('puerta', 21),
#  ('trágico', 21),
#  ('concienciar', 21),
#  ('apacible', 21),
#  ('niebla', 21),
#  ('juntar', 21),
#  ('cumbre', 21),
#  ('crecer', 21),
#  ('humilde', 21),
#  ('sabio', 21),
#  ('fugar', 21),
#  ('caridad', 21),
#  ('pequeño', 21),
#  ('cerrar', 21),
#  ('pedir', 21),
#  ('espantar', 21),
#  ('criatura', 21),
#  ('pasear', 21),
#  ('luto', 21),
#  ('laboratorio', 20),
#  ('perseguir', 20),
#  ('sordo', 20),
#  ('llenar', 20),
#  ('añadir', 20),
#  ('interés', 20),
#  ('descubrir', 20),
#  ('virtud', 20),
#  ('causar', 20),
#  ('firmar', 20),
#  ('admiración', 20),
#  ('cortar', 20),
#  ('marinero', 20),
#  ('papel', 20),
#  ('volar', 20),
#  ('enfermo', 20),
#  ('visitar', 20),
#  ('boca', 20),
#  ('santo', 20),
#  ('freír', 20),
#  ('rincón', 20),
#  ('propósito', 20),
#  ('mudo', 20),
#  ('soledad', 20),
#  ('--es', 20),
#  ('nene', 20),
#  ('encender', 20),
#  ('servir', 20),
#  ('noticiar', 20),
#  ('sonriente', 19),
#  ('erguir', 19),
#  ('tímido', 19),
#  ('estremecer', 19),
#  ('sutil', 19),
#  ('aparecer', 19),
#  ('aguardar', 19),
#  ('juvenil', 19),
#  ('emocionar', 19),
#  ('pesadumbre', 19),
#  ('inclinar', 19),
#  ('destinar', 19),
#  ('ímpetu', 19),
#  ('semejante', 19),
#  ('envolver', 19),
#  ('mediar', 19),
#  ('señalar', 19),
#  ('cabo', 19),
#  ('gustar', 19),
#  ('cuerpo', 19),
#  ('ansia', 19),
#  ('singular', 19),
#  ('súbito', 19),
#  ('cobarde', 18),
#  ('dorar', 18),
#  ('llanto', 18),
#  ('cercar', 18),
#  ('árbol', 18),
#  ('remoto', 18),
#  ('forzar', 18),
#  ('rodar', 18),
#  ('camino', 18),
#  ('preso', 18),
#  ('acabar', 18),
#  ('infinito', 18),
#  ('gracia', 18),
#  ('gratitud', 18),
#  ('amoroso', 18),
#  ('angustiar', 18),
#  ('nacer', 18),
#  ('varonil', 18),
#  ('jardín', 18),
#  ('enorme', 18),
#  ('vivo', 18),
#  ('solemne', 18),
#  ('iniciar', 18),
#  ('cristal', 18),
#  ('profundar', 18),
#  ('adiós', 18),
#  ('carácter', 18),
#  ('consolar', 18),
#  ('lecho', 18),
#  ('ibarrola', 18),
#  ('rojo', 18),
#  ('divino', 18),
#  ('saltar', 18),
#  ('único', 18),
#  ('imaginar', 18),
#  ('tembloroso', 17),
#  ('esconder', 17),
#  ('extraño', 17),
#  ('impulsar', 17),
#  ('temer', 17),
#  ('elegante', 17),
#  ('fugitivo', 17),
#  ('duro', 17),
#  ('débil', 17),
#  ('voluntad', 17),
#  ('gente', 17),
#  ('carlitos', 17),
#  ('sueño', 17),
#  ('dió', 17),
#  ('ausentar', 17),
#  ('desdén', 17),
#  ('asegurar', 17),
#  ('hombro', 17),
#  ('guardar', 17),
#  ('tocar', 17),
#  ('descansar', 17),
#  ('oculto', 17),
#  ('mamá', 17),
#  ('ciencia', 17),
#  ('rezar', 17),
#  ('carne', 17),
#  ('hundir', 17),
#  ('figurar', 17),
#  ('peregrino', 17),
#  ('hondo', 17),
#  ('mezclar', 17),
#  ('infeliz', 17),
#  ('dedo', 17),
#  ('arrabal', 17),
#  ('rumorar', 17),
#  ('libro', 17),
#  ('devoto', 17),
#  ('extender', 17),
#  ('suave', 17),
#  ('traer', 17),
#  ('familiar', 17),
#  ('doncella', 17),
#  ('orar', 17),
#  ('\ufeff1', 16),
#  ('esforzar', 16),
#  ('ligero', 16),
#  ('herir', 16),
#  ('playa', 16),
#  ('razón', 16),
#  ('rumbo', 16),
#  ('arrebatar', 16),
#  ('suceso', 16),
#  ('balbucir', 16),
#  ('azul', 16),
#  ('españolar', 16),
#  ('gemir', 16),
#  ('burlar', 16),
#  ('cama', 16),
#  ('sendero', 16),
#  ('sombrío', 16),
#  ('puro', 16),
#  ('ala', 16),
#  ('interrogar', 16),
#  ('lástima', 16),
#  ('costumbre', 16),
#  ('prender', 16),
#  ('estancia', 16),
#  ('muelle', 16),
#  ('grupo', 16),
#  ('orgullo', 16),
#  ('--ya', 16),
#  ('espumar', 15),
#  ('infancia', 15),
#  ('fruto', 15),
#  ('sacrificio', 15),
#  ('febril', 15),
#  ('promesa', 15),
#  ('despertar', 15),
#  ('acudir', 15),
#  ('atormentar', 15),
#  ('casita', 15),
#  ('pretender', 15),
#  ('desear', 15),
#  ('atravesar', 15),
#  ('aventurar', 15),
#  ('abismar', 15),
#  ('robledal', 15),
#  ('pronunciar', 15),
#  ('razonar', 15),
#  ('encimar', 15),
#  ('conmover', 15),
#  ('ruta', 15),
#  ('empujar', 15),
#  ('imaginación', 15),
#  ('cambiar', 15),
#  ('empezar', 15),
#  ('personar', 15),
#  ('confundir', 15),
#  ('fermín', 15),
#  ('perfumar', 15),
#  ('anunciar', 15),
#  ('aromar', 15),
#  ('rumor', 15),
#  ('naturaleza', 15),
#  ('salud', 15),
#  ('escribir', 15),
#  ('quebrantar', 15),
#  ('crepúsculo', 15),
#  ('despedir', 15),
#  ('maridar', 15),
#  ('arrogante', 15),
#  ('doliente', 15),
#  ('afán', 15),
#  ('latir', 15),
#  ('misericordia', 15),
#  ('doblar', 14),
#  ('recibir', 14),
#  ('bravo', 14),
#  ('mecer', 14),
#  ('desierto', 14),
#  ('echar', 14),
#  ('novedad', 14),
#  ('hechizar', 14),
#  ('impacientar', 14),
#  ('ocultar', 14),
#  ('venturo', 14),
#  ('entrañar', 14),
#  ('absorto', 14),
#  ('luna', 14),
#  ('encantar', 14),
#  ('alegría', 14),
#  ('acordar', 14),
#  ('recio', 14),
#  ('turbio', 14),
#  ('presentar', 14),
#  ('brotar', 14),
#  ('cansar', 14),
#  ('humano', 14),
#  ('secreto', 14),
#  ('quedo', 14),
#  ('orillar', 14),
#  ('rápido', 14),
#  ('resplandor', 14),
#  ('cansancio', 14),
#  ('fingir', 14),
#  ('valiente', 14),
#  ('amistar', 14),
#  ('comprender', 14),
#  ('ribera', 14),
#  ('soplar', 14),
#  ('cubrir', 14),
#  ('gabinete', 14),
#  ('nave', 14),
#  ('fugaz', 14),
#  ('femenino', 14),
#  ('montaña', 14),
#  ('perdonar', 14),
#  ('compasión', 14),
#  ('isla', 14),
#  ('disimular', 14),
#  ('vallar', 14),
#  ('allá', 14),
#  ('cabello', 14),
#  ('girar', 13),
#  ('interesante', 13),
#  ('atrever', 13),
#  ('cuyo', 13),
#  ('oración', 13),
#  ('--¿qué', 13),
#  ('posar', 13),
#  ('realidad', 13),
#  ('absoluto', 13),
#  ('menester', 13),
#  ('ilusión', 13),
#  ('curar', 13),
#  ('fácil', 13),
#  ('vano', 13),
#  ('penumbra', 13),
#  ('sospechar', 13),
#  ('belleza', 13),
#  ('puerto', 13),
#  ('sensación', 13),
#  ('culpar', 13),
#  ('amanecer', 13),
#  ('instinto', 13),
#  ('abrazar', 13),
#  ('palacio', 13),
#  ('porvenir', 13),
#  ('perfilar', 13),
#  ('sentimental', 13),
#  ('agitar', 13),
#  ('esposar', 13),
#  ('amargar', 13),
#  ('lejano', 13),
#  ('amable', 13),
#  ('verde', 13),
#  ('juzgar', 13),
#  ('matrimoniar', 13),
#  ('ilustrar', 13),
#  ('repentino', 13),
#  ('--¿no', 13),
#  ('consultar', 13),
#  ('sonar', 13),
#  ('codiciar', 13),
#  ('alarmar', 13),
#  ('acompañar', 13),
#  ('miar', 13),
#  ('confidencia', 12),
#  ('ausencia', 12),
#  ('heroico', 12),
#  ('suceder', 12),
#  ('fantasía', 12),
#  ('meditación', 12),
#  ('errante', 12),
#  ('grave', 12),
#  ('lumbre', 12),
#  ('solicitud', 12),
#  ('difícil', 12),
#  ('siquiera', 12),
#  ('suerte', 12),
#  ('boticario', 12),
#  ('penetrar', 12),
#  ('durmiente', 12),
#  ('revelación', 12),
#  ('discípulo', 12),
#  ('medroso', 12),
#  ('crisis', 12),
#  ('adivinar', 12),
#  ('delicado', 12),
#  ('leer', 12),
#  ('violento', 12),
#  ('cumplir', 12),
#  ('astro', 12),
#  ('galante', 12),
#  ('movimiento', 12),
#  ('aposentar', 12),
#  ('deseo', 12),
#  ('reposar', 12),
#  ('extrañar', 12),
#  ('intimidar', 12),
#  ('acariciar', 12),
#  ('rico', 12),
#  ('marchar', 12),
#  ('mover', 12),
#  ('--pero', 12),
#  ('montar', 12),
#  ('altura', 12),
#  ('inspirar', 12),
#  ('apagar', 12),
#  ('beso', 12),
#  ('ansiedad', 12),
#  ('vehemente', 12),
#  ('carta', 12),
#  ('romántico', 12),
#  ('prometer', 12),
#  ('inteligencia', 12),
#  ('prisa', 12),
#  ('alcanzar', 11),
#  ('amargo', 11),
#  ('hastiar', 11),
#  ('contestar', 11),
#  ('color', 11),
#  ('heredia', 11),
#  ('estrada', 11),
#  ('hoja', 11),
#  ('conversación', 11),
#  ('ordóñez', 11),
#  ('apoyar', 11),
#  ('decidir', 11),
#  ('bondad', 11),
#  ('implacable', 11),
#  ('surgir', 11),
#  ('paz', 11),
#  ('avanzar', 11),
#  ('inútil', 11),
#  ('juez', 11),
#  ('rendir', 11),
#  ('incertidumbre', 11),
#  ('melancólico', 11),
#  ('viajar', 11),
#  ('afanar', 11),
#  ('levar', 11),
#  ('enemigo', 11),
#  ('virgen', 11),
#  ('veloz', 11),
#  ('sagrado', 11),
#  ('elegir', 11),
#  ('niñez', 11),
#  ('colocar', 11),
#  ('amargura', 11),
#  ('rotar', 11),
#  ('mudar', 11),
#  ('risueño', 11),
#  ('ajeno', 11),
#  ('alonso', 11),
#  ('barquín', 11),
#  ('sofá', 11),
#  ('real', 11),
#  ('bárbaro', 11),
#  ('brío', 11),
#  ('amador', 11),
#  ('torturar', 11),
#  ('trémulo', 11),
#  ('alumbrar', 11),
#  ('pupilo', 11),
#  ('temor', 11),
#  ('admirable', 11),
#  ('maternal', 11),
#  ('cuidar', 11),
#  ('recién', 11),
#  ('fuente', 11),
#  ('desaparecer', 11),
#  ('estrellar', 11),
#  ('continuar', 11),
#  ('--yo', 11),
#  ('francés', 11),
#  ('vencer', 11),
#  ('componer', 11),
#  ('aprender', 11),
#  ('luminoso', 11),
#  ('doloroso', 11),
#  ('ingenuo', 11),
#  ('henchir', 11),
#  ('rondar', 11),
#  ('oprimir', 11),
#  ('melancolía', 11),
#  ('imposible', 11),
#  ('hotel', 11),
#  ('montañés', 11),
#  ('mesar', 11),
#  ('salón', 11),
#  ('sostener', 11),
#  ('precisar', 10),
#  ('inmenso', 10),
#  ('flotar', 10),
#  ('gracioso', 10),
#  ('doncel', 10),
#  ('triunfar', 10),
#  ('indefinible', 10),
#  ('bahía', 10),
#  ('descender', 10),
#  ('calor', 10),
#  ('sonreir', 10),
#  ('recobrar', 10),
#  ('ráfaga', 10),
#  ('inquieto', 10),
#  ('esclavo', 10),
#  ('lento', 10),
#  ('escena', 10),
#  ('alejar', 10),
#  ('brusco', 10),
#  ('protestar', 10),
#  ('zozobrar', 10),
#  ('pasajero', 10),
#  ('fuego', 10),
#  ('apariencia', 10),
#  ('público', 10),
#  ('jurar', 10),
#  ('apasionar', 10),
#  ('recoger', 10),
#  ('disponer', 10),
#  ('sollozar', 10),
#  ('peregrinar', 10),
#  ('mártir', 10),
#  ('sangrar', 10),
#  ('tren', 10),
#  ('yacer', 10),
#  ('coche', 10),
#  ('ángel', 10),
#  ('ley', 10),
#  ('patrio', 10),
#  ('nido', 10),
#  ('encoger', 10),
#  ('blando', 10),
#  ('segundar', 10),
#  ('florecer', 10),
#  ('salvar', 10),
#  ('tranquilo', 10),
#  ('impaciencia', 10),
#  ('entendimiento', 10),
#  ('aspecto', 10),
#  ('musa', 10),
#  ('ambicionar', 10),
#  ('risa', 10),
#  ('papá', 10),
#  ('desventura', 10),
#  ('sacerdote', 10),
#  ('víctima', 10),
#  ('o', 10),
#  ('producir', 10),
#  ('relatar', 10),
#  ('fiebre', 10),
#  ('antiguo', 10),
#  ('poseer', 10),
#  ('sublimar', 10),
#  ('precioso', 10),
#  ('peligrar', 10),
#  ('sembrar', 10),
#  ('despierto', 10),
#  ('fortuna', 10),
#  ('confusión', 10),
#  ('escéptico', 10),
#  ('caña', 10),
#  ('plantar', 10),
#  ('manantial', 10),
#  ('plácido', 9),
#  ('cobardía', 9),
#  ('malo', 9),
#  ('pleno', 9),
#  ('--¿por', 9),
#  ('rozar', 9),
#  ('arrancar', 9),
#  ('indiferencia', 9),
#  ('jamás', 9),
#  ('afirmar', 9),
#  ('fracasar', 9),
#  ('obrar', 9),
#  ('inmóvil', 9),
#  ('especie', 9),
#  ('aludir', 9),
#  ('horrible', 9),
#  ('ruido', 9),
#  ('acostar', 9),
#  ('ensoñar', 9),
#  ('locura', 9),
#  ('durar', 9),
#  ('ocurrir', 9),
#  ('brisa', 9),
#  ('precoz', 9),
#  ('retratar', 9),
#  ('turbar', 9),
#  ('tremendo', 9),
#  ('quietud', 9),
#  ('difunto', 9),
#  ('blandura', 9),
#  ('mueca', 9),
#  ('arrastrar', 9),
#  ('regresar', 9),
#  ('admirar', 9),
#  ('monstruo', 9),
#  ('lindar', 9),
#  ('noto', 9),
#  ('hostil', 9),
#  ('par', 9),
#  ('áspero', 9),
#  ('refugiar', 9),
#  ('hábito', 9),
#  ('fatal', 9),
#  ('fatigar', 9),
#  ('enojar', 9),
#  ('velascos', 9),
#  ('arder', 9),
#  ('cadena', 9),
#  ('silbar', 9),
#  ('límite', 9),
#  ('nativo', 9),
#  ('nervioso', 9),
#  ('gabriel', 9),
#  ('rodilla', 9),
#  ('cuartar', 9),
#  ('espectáculo', 9),
#  ('libertar', 9),
#  ('plan', 9),
#  ('humanar', 9),
#  ('puño', 9),
#  ('dibujar', 9),
#  ('leyenda', 9),
#  ('improvisar', 9),
#  ('población', 9),
#  ('ademán', 9),
#  ('insigne', 9),
#  ('audaz', 9),
#  ('presenciar', 9),
#  ('emprender', 9),
#  ('minuto', 9),
#  ('cegar', 9),
#  ('enfermar', 9),
#  ('jirón', 9),
#  ('resolución', 9),
#  ('falto', 9),
#  ('antojo', 9),
#  ('frío', 9),
#  ('salar', 9),
#  ('beber', 9),
#  ('grito', 9),
#  ('regalar', 9),
#  ('primavera', 9),
#  ('compañero', 9),
#  ('blandir', 9),
#  ('raíz', 9),
#  ('amenazar', 9),
#  ('escapar', 9),
#  ('necesitar', 9),
#  ('resistir', 9),
#  ('derecho', 9),
#  ('habitación', 9),
#  ('altivez', 9),
#  ('ansioso', 9),
#  ('gloria', 9),
#  ('devoción', 9),
#  ('inquirir', 9),
#  ('comenzar', 9),
#  ('salvaje', 9),
#  ('culpable', 9),
#  ('atención', 9),
#  ('mariposa', 9),
#  ('adquirir', 9),
#  ('voluble', 9),
#  ('existir', 8),
#  ('halago', 8),
#  ('merecer', 8),
#  ('alfombrar', 8),
#  ('abajar', 8),
#  ('interrumpir', 8),
#  ('perder', 8),
#  ('hilar', 8),
#  ('despechar', 8),
#  ('hollar', 8),
#  ('chiquitín', 8),
#  ('cordial', 8),
#  ('replicar', 8),
#  ('murmullar', 8),
#  ('espalda', 8),
#  ('avisar', 8),
#  ('pisar', 8),
#  ('contener', 8),
#  ('desesperar', 8),
#  ('excursión', 8),
#  ('benigno', 8),
#  ('huraño', 8),
#  ('aurora', 8),
#  ('divertir', 8),
#  ('certidumbre', 8),
#  ('camarada', 8),
#  ('rayar', 8),
#  ('vago', 8),
#  ('vecino', 8),
#  ('pendiente', 8),
#  ('egoísta', 8),
#  ('convertir', 8),
#  ('ferviente', 8),
#  ('deshacer', 8),
#  ('clamar', 8),
#  ('maravillar', 8),
#  ('vagamente', 8),
#  ('compasivo', 8),
#  ('conformar', 8),
#  ('lluvia', 8),
#  ('torpe', 8),
#  ('servidumbre', 8),
#  ('sangriento', 8),
#  ('milagro', 8),
#  ('vagar', 8),
#  ('mil', 8),
#  ('soñador', 8),
#  ('lívido', 8),
#  ('rebeldía', 8),
#  ('dintel', 8),
#  ('lindo', 8),
#  ('negar', 8),
#  ('generoso', 8),
#  ('saludable', 8),
#  ('interesar', 8),
#  ('finar', 8),
#  ('lamentar', 8),
#  ('--¡pobre', 8),
#  ('quédase', 8),
#  ('cautivo', 8),
#  ('piel', 8),
#  ('sepulcro', 8),
#  ('espantoso', 8),
#  ('comentar', 8),
#  ('fuerza', 8),
#  ('entornar', 8),
#  ('convenir', 8),
#  ('cabellar', 8),
#  ('fino', 8),
#  ('solitario', 8),
#  ('estación', 8),
#  ('ropa', 8),
#  ('inconsciente', 8),
#  ('sentíase', 8),
#  ('dormitorio', 8),
#  ('corriente', 8),
#  ('alcoy', 8),
#  ('humildad', 8),
#  ('quieto', 8),
#  ('--el', 8),
#  ('espiritual', 8),
#  ('romero', 8),
#  ('inerte', 8),
#  ('apremiante', 8),
#  ('poderoso', 8),
#  ('obscuridad', 8),
#  ('roca', 8),
#  ('artista', 8),
#  ('únicamente', 8),
#  ('desgraciar', 8),
#  ('orgulloso', 8),
#  ('gris', 8),
#  ...]

# %% [markdown]
# ### Encontrar personajes

# %%
# tipos de entidades presentes en el texto
set(ent.label_ for ent in proc_text.ents)
# Out:
# {'LOC', 'MISC', 'ORG', 'PER'}

# %%
characters = Counter()
# De la documentación de spacy una "named entity" es cualquier objeto del mundo real como una persona,
# ubicación, organización o producto con un nombre propio. Utilizaremos las 'named entities' para encontrar los nombres 
# de personas mas comunes en el texto, suponiendo que estos serán los personajes principales.


for nam_ent in proc_text.ents:
    if nam_ent.label_ == 'PER':
        characters[nam_ent.lemma_] += 1

characters.most_common()
# Out:
# [('Regina', 104),
#  ('Carlota', 74),
#  ('Carlos', 63),
#  ('Ana María', 56),
#  ('Adolfo', 54),
#  ('Manuel', 52),
#  ('Pero', 38),
#  ('Velasquín', 37),
#  ('Daniel', 33),
#  ('Jaime', 29),
#  ('Marta', 28),
#  ('Y', 28),
#  ('Pablo', 26),
#  ('Velasco', 23),
#  ('', 22),
#  ('De', 18),
#  ('don Celso', 17),
#  ('Así', 15),
#  ('El', 13),
#  ('La', 12),
#  ('Al', 11),
#  ('Robledo _', 11),
#  ('Mercedes', 10),
#  ('Amador', 9),
#  ('Fué', 9),
#  ('No', 9),
#  ('Estrada', 8),
#  ('Ella', 8),
#  ('Carlos Ramírez', 8),
#  ('Ibarrola', 8),
#  ('Eugenia', 7),
#  ('Allí', 7),
#  ('Después', 6),
#  ('Mas', 6),
#  ('Timonel _', 6),
#  ('Jaime de Alcántara', 6),
#  ('Dios', 6),
#  ('¡ Qué', 6),
#  ('Juan Ramírez', 6),
#  ('Manuel Velasco', 6),
#  ('Aquella', 5),
#  ('Pero Regina', 5),
#  ('Aquel', 5),
#  ('Ya', 4),
#  ('Va', 4),
#  ('Por', 4),
#  ('Las', 4),
#  ('Rolando', 4),
#  ('En', 4),
#  ('Carlitos Ramírez', 4),
#  ('Ha', 4),
#  ('Con', 4),
#  ('don Juan', 4),
#  ('Había', 4),
#  ('Alonso', 4),
#  ('Gabriel _', 4),
#  ('Marín', 3),
#  ('Fabricio', 3),
#  ('Carlota de Heredia', 3),
#  ('Mi', 3),
#  ('Aún', 3),
#  ('Felipe Alonso', 3),
#  ('Se', 3),
#  ('Filomena', 3),
#  ('¡ Oh', 3),
#  ('Qué', 3),
#  ('Doña Mercedes', 3),
#  ('Ordóñez', 3),
#  ('Lazareto', 3),
#  ('Felipe \n Alonso', 3),
#  ('A', 3),
#  ('Sin', 3),
#  ('Adolfo Velasco', 3),
#  ('Está', 3),
#  ('Era', 3),
#  ('Un', 3),
#  ('Mientras', 3),
#  ('Danielito', 3),
#  ('Celso Ortiz', 3),
#  ('Velascos', 3),
#  ('Anda', 2),
#  ('Escucha', 2),
#  ('Reina', 2),
#  ('Los', 2),
#  ('Y Regina', 2),
#  ('doctor Marín', 2),
#  ('Ana \n María', 2),
#  ('En vano Regina', 2),
#  ('Luego', 2),
#  ('Acuérdate', 2),
#  ('Quedó', 2),
#  ('lo Virgen', 2),
#  ('Todos', 2),
#  ('¡ Pero', 2),
#  ('Sabe', 2),
#  ('Cuanto', 2),
#  ('¡ Carlos', 2),
#  ('Jacoba', 2),
#  ('Esto', 2),
#  ('¡ Reina', 2),
#  ('Llegando', 2),
#  ('Una', 2),
#  ('Aquí', 2),
#  ('Paco \n Ordóñez', 2),
#  ('Alzó', 2),
#  ('Toda', 2),
#  ('Saltó', 2),
#  ('Examinó', 2),
#  ('Reina _', 2),
#  ('Dolores', 2),
#  ('Jacinto Ibarrola', 2),
#  ('Océano', 2),
#  ('Carlos \n Ramírez', 2),
#  ('Filo', 2),
#  ('Le', 2),
#  ('Pero Velasquín', 2),
#  ('Si', 2),
#  ('Muchas', 2),
#  ('Roto', 2),
#  ('Tal', 2),
#  ('Yo', 2),
#  ('La de Alcántara', 2),
#  ('Y Velasco', 2),
#  ('Musa', 2),
#  ('Aunque', 2),
#  ('También', 2),
#  ('Silvia _', 2),
#  ('Gabriela _', 2),
#  ('don Fermín', 2),
#  ('Dejó', 2),
#  ('Ya Regina', 2),
#  ('Ricardo I', 1),
#  ('¡ Rolando !', 1),
#  ('¡ Oh !', 1),
#  ('Velasquín _', 1),
#  ('lord Byron', 1),
#  ('Halló Adolfo', 1),
#  ('Jamás', 1),
#  ('Beatriz', 1),
#  ('Su', 1),
#  ('Locas', 1),
#  ('¡ Tampoco', 1),
#  ('Quise', 1),
#  ('Mejor', 1),
#  ('Aplazando', 1),
#  ('Cuando Carlota', 1),
#  ('Nuño de Rasura', 1),
#  ('Pania della Croce', 1),
#  ('Olvida Carlos', 1),
#  ('Parecióle', 1),
#  ('Afirmando', 1),
#  ('¡ Adiós', 1),
#  ('Medrosa', 1),
#  ('Del', 1),
#  ('Todo', 1),
#  ('Repitió', 1),
#  ('Quedan', 1),
#  ('Calmada', 1),
#  ('Danielitos', 1),
#  ('Sentados', 1),
#  ('Lloro', 1),
#  ('Pero á Regina', 1),
#  ('Robledo', 1),
#  ('Las cuita de', 1),
#  ('Detrás', 1),
#  ('Estas', 1),
#  ('Paco Ordóñez', 1),
#  ('Alentado Carlos', 1),
#  ('Mercedes \n llegar', 1),
#  ('Huyendo Velasquín', 1),
#  ('Lain Calvo', 1),
#  ('Aquel \n rumbo', 1),
#  ('Estraduca', 1),
#  ('Absorto', 1),
#  ('Cuando', 1),
#  ('Estrechóse', 1),
#  ('! Aseguro', 1),
#  ('Era lo', 1),
#  ('Desdeña', 1),
#  ('Convencida', 1),
#  ('Rafael Marín', 1),
#  ('Bajo', 1),
#  ('Daniel de \n Alcántara', 1),
#  ('Don Celso Ortiz', 1),
#  ('Bajó', 1),
#  ('Afirman', 1),
#  ('Admites', 1),
#  ('Hace Regina', 1),
#  ('Aconteció', 1),
#  ('Enrojece Carlos', 1),
#  ('Pálido', 1),
#  ('Duda', 1),
#  ('Receloso', 1),
#  ('Pasado', 1),
#  ('Huyendo', 1),
#  ('Jesús ... Amor ... Amor ... !', 1),
#  ('Levantó', 1),
#  ('¡ Reina !', 1),
#  ('Ligera', 1),
#  ('Largo', 1),
#  ('Gustaron', 1),
#  ('Avanza Regina', 1),
#  ('Juana lo Loca', 1),
#  ('Tímido \n Velasquín', 1),
#  ('Dryden', 1),
#  ('Auderico ... Más', 1),
#  ('Ana María Ramírez', 1),
#  ('Ana María !', 1),
#  ('América', 1),
#  ('Adivinando', 1),
#  ('España', 1),
#  ('Entra don Fermín', 1),
#  ('Estaba', 1),
#  ('Sonríe Eugenia', 1),
#  ('Callaba', 1),
#  ('Carlota!--lamentó Regina.--_Bella', 1),
#  ('Aparecen', 1),
#  ('Vuelve Marta', 1),
#  ('Canción', 1),
#  ('Ya saber', 1),
#  ('Oculta', 1),
#  ('Daniel de Alcántara', 1),
#  ('Melpómene', 1),
#  ('Excitados', 1),
#  ('Evita', 1),
#  ('Influía', 1),
#  ('María', 1),
#  ('Ayudándole Regina', 1),
#  ('Nota Regina', 1),
#  ('Alah', 1),
#  ('Ved', 1),
#  ('Amador Olmeda', 1),
#  ('Grande', 1),
#  ('Amaba Regina', 1),
#  ('Después de', 1),
#  ('Mon', 1),
#  ('Había jugar Regina', 1),
#  ('Cumplirá', 1),
#  ('Salen', 1),
#  ('Bella', 1),
#  ('Declina', 1),
#  ('Habló', 1),
#  ('Irguióse \n arrogante', 1),
#  ('¡ Hèlas !', 1),
#  ('Meyerbeer', 1),
#  ('Galán', 1),
#  ('Walter Scott', 1),
#  ('Oriundo de Torremar', 1),
#  ('Renan', 1),
#  ('Corazón de León', 1),
#  ('Comenzó', 1),
#  ('Paco', 1),
#  ('Apareciósele', 1),
#  ('Adolfo querer', 1),
#  ('Murieron', 1),
#  ('Crece', 1),
#  ('Espronceda', 1),
#  ('Dice Carlos', 1),
#  ('Alzó Regina', 1),
#  ('Y Pablo', 1),
#  ('Dante \n Alighieri', 1),
#  ('Hizo', 1),
#  ('Menudo', 1),
#  ('Abandonada', 1),
#  ('Sale', 1),
#  ('Adolfo á Pablo', 1),
#  ('Recordando', 1),
#  ('¡ Amor !', 1),
#  ('Rara', 1),
#  ('Ciñéronse', 1),
#  ('Rey', 1),
#  ('Manuel . Buscan', 1),
#  ('Sigfredo', 1),
#  ('Nos', 1),
#  ('Asustado', 1),
#  ('Lo', 1),
#  ('Preguntábale', 1),
#  ('Enciende', 1),
#  ('Leandro', 1),
#  ('Forjóse', 1),
#  ('Rodaban', 1),
#  ('Adolfo ... Sí', 1),
#  ('Píndaro', 1),
#  ('Filomena Bernaldo', 1),
#  ('Calló Pablo', 1),
#  ('Ana María ?', 1),
#  ('Volvió Regina', 1),
#  ('Estaba Regina', 1),
#  ('Musa _', 1),
#  ('Partieron', 1),
#  ('Aquel \n escepticismo', 1),
#  ('Sintiendo estar Regina', 1),
#  ('¡ Vamos', 1),
#  ('El viejuco', 1),
#  ('Alza Regina', 1),
#  ('aposentar de Regina', 1),
#  ('Temeroso', 1),
#  ('Mercedes \n tampoco', 1),
#  ('Nápoles', 1),
#  ('Como', 1),
#  ('¡ Ah !', 1),
#  ('Meditando lo de Alcántara', 1),
#  ('Movido \n Adolfo', 1),
#  ('casar de Regina', 1),
#  ('Y ver Regina', 1),
#  ('Adolfo \n tétrico', 1),
#  ('Apartóse Regina', 1),
#  ('Y pronunciar Regina', 1),
#  ('Dolores Barquín', 1),
#  ('Decíase', 1),
#  ('Dueña', 1),
#  ('Fielberg', 1),
#  ('Santiago', 1),
#  ('Mientras acomodar Marta', 1),
#  ('Acaso Jaime', 1),
#  ('Ya estar Ordóñez', 1),
#  ('Mas don Fermín', 1),
#  ('Obstinado', 1),
#  ('Acometiendo', 1),
#  ('Schiller', 1),
#  ('Cuantas', 1),
#  ('Eugenia vistióse Regina', 1),
#  ('Van - Dyck', 1),
#  ('Convulsa', 1),
#  ('Ave', 1),
#  ('Oyó Pablo', 1),
#  ('Velasquita', 1),
#  ('Hostigaba Regina', 1),
#  ('Acude Eugenia', 1),
#  ('Debían', 1),
#  ('Como el _', 1),
#  ('Beatriz de Galindo . \n\n Lleva Regina', 1),
#  ('Sonaba', 1),
#  ('Evadiendo', 1),
#  ('Hundió', 1),
#  ('Viéndole', 1),
#  ('Victoriano !', 1),
#  ("Gabriel \n d'Annunzio", 1),
#  ('Triste', 1),
#  ('Robledo_. Mamá', 1),
#  ('Sorprendiéndolas', 1),
#  ('Sentíase Regina', 1),
#  ('Adolfo \n Velasco', 1),
#  ('Hundes', 1),
#  ('Dinero', 1),
#  ('Murió', 1),
#  ('Tres', 1),
#  ('Juntamente', 1),
#  ('Torremar', 1),
#  ('Flores', 1),
#  ('Creerías', 1),
#  ('Muerde Paco Ordóñez', 1),
#  ('Juzgóse', 1),
#  ('Estériles', 1),
#  ('Más', 1),
#  ('Apenas', 1),
#  ('Espigaba', 1),
#  ('¡ Jamás', 1),
#  ('Volviéronse', 1),
#  ('Sí', 1),
#  ('Reía', 1),
#  ('Regina.--¿Creerás', 1),
#  ('¡ Era', 1),
#  ('Cantábrico', 1),
#  ('Juan!--compadeció Velasco', 1),
#  ('Fabricio Bernaldo', 1),
#  ('Rió', 1),
#  ('Entretanto', 1),
#  ('Mísera', 1),
#  ('AMÉRICA!--EL MAR', 1),
#  ('Aprendió Regina', 1),
#  ('Liviana', 1),
#  ('¡ Hijo', 1),
#  ('Arrepentido Manuel', 1),
#  ('Heredia', 1),
#  ('Paco Ordoñez', 1),
#  ('Sentía Carlota', 1),
#  ('Tiende', 1),
#  ('Quisiera', 1),
#  ('Siempre', 1),
#  ('Salió', 1),
#  ('Flos Sanctorum', 1),
#  ('Anhelosa', 1),
#  ('Fermín', 1),
#  ('Trata', 1),
#  ('Embriagada', 1),
#  ('Teníamos', 1),
#  ('Pasaba', 1),
#  ('Hacían', 1),
#  ('Madre', 1),
#  ('Adolfo y Regina', 1),
#  ('Obra', 1),
#  ('Adónde', 1),
#  ('Otras', 1),
#  ('¡ Gabriel !', 1),
#  ('Envuelta', 1),
#  ('Llevó', 1),
#  ('Acaso', 1),
#  ('Todas', 1),
#  ('Juntas', 1),
#  ('Mueve', 1),
#  ('Logró Velasco', 1),
#  ('Watteau', 1),
#  ('Rumores', 1),
#  ('Segura estar Regina', 1),
#  ('Juan', 1),
#  ('Pero Jaime', 1),
#  ('Murmuraba', 1),
#  ('Ni', 1),
#  ('Cuando Regina', 1),
#  ('Lentamente', 1),
#  ('Huyó', 1),
#  ('Absorta Ana María', 1),
#  ('¡ Carlota', 1),
#  ('Saca', 1),
#  ('¡ Tengo', 1),
#  ('Volvió', 1),
#  ('Aderezó', 1),
#  ('Contempla', 1),
#  ('Era Manuel Velasco', 1),
#  ('Punzada', 1),
#  ('Contempla Ordóñez', 1),
#  ('Venus', 1),
#  ('Salta', 1),
#  ('Supone', 1),
#  ('¡ Tal', 1),
#  ('Adiviné', 1),
#  ('Mirando', 1),
#  ('Domeñadas', 1),
#  ('Alza', 1),
#  ('Hasta don Juan Ramírez', 1),
#  ('Reflejo', 1),
#  ('Esconde Carlos', 1),
#  ('Victoriano Estrada', 1),
#  ('Pone', 1),
#  ('Componían', 1),
#  ('Lúcida', 1),
#  ('Solía', 1),
#  ('Era Carlos', 1),
#  ('padre de Regina', 1),
#  ('Quedóse', 1),
#  ('Entraron', 1),
#  ('Pietra Pane _', 1),
#  ('Niegan', 1),
#  ('Allá', 1),
#  ('--Júrame', 1),
#  ('Joven', 1),
#  ('Conoce', 1),
#  ('Recuerda Regina', 1),
#  ('Harto', 1),
#  ('Schopenhauer', 1),
#  ('Dispuesto Jaime', 1),
#  ('Recae', 1),
#  ('Crujen', 1),
#  ('Bello', 1),
#  ('El farmacéutico', 1),
#  ('Lleva', 1),
#  ('Las Américas', 1),
#  ('También sentir Regina', 1),
#  ('Confuso Manuel', 1),
#  ('Arrobada', 1),
#  ('Mirábale Carlota', 1),
#  ('María!--murmuró Velasquín', 1),
#  ('Dirigiéndose', 1),
#  ('Astuta', 1),
#  ('Confundiendo \n el', 1),
#  ('Derivó', 1),
#  ('Hace', 1),
#  ('San Marcos', 1),
#  ('Niezstche', 1),
#  ('Ojos', 1),
#  ('Manso', 1),
#  ('Garcilaso de lo Vega', 1),
#  ('Ramírez', 1),
#  ('Razonando', 1),
#  ('El desconsolar de Pablo', 1),
#  ('Eran', 1),
#  ('Esta', 1),
#  ('La mirar Regina', 1),
#  ('Lanzóse', 1),
#  ('Crevaux', 1),
#  ('Sorprende á Regina', 1),
#  ('Robledo_. \n Ana María', 1),
#  ('Algo', 1),
#  ('Pasamos', 1),
#  ('Para Carlota', 1),
#  ('Ondulan', 1),
#  ('Este', 1),
#  ('Agonizaba', 1),
#  ('Por fortuna', 1),
#  ('Pasa', 1),
#  ('Hace Marta', 1),
#  ('Shakespeare', 1),
#  ('De \n hinojo', 1),
#  ('Fué Dolores', 1),
#  ('Sólo', 1),
#  ('Gloriándose', 1),
#  ('Busca', 1),
#  ('Carlota Heredia', 1),
#  ('Quédase', 1),
#  ('Regina:--¿España ?--', 1),
#  ('Juana de Arco', 1),
#  ('Casi', 1),
#  ('Puesto', 1),
#  ('Quedóse lo de Alcántara', 1),
#  ('Eugenia Barquín', 1),
#  ('Entorna Regina', 1),
#  ('Bocaccio', 1),
#  ('Miraba', 1),
#  ('Sube', 1),
#  ('Trocó Regina', 1),
#  ('Diana', 1),
#  ('Arreció', 1),
#  ('¡ Figúrese', 1),
#  ('Levanta', 1),
#  ('Dios!--balbuce Eugenia', 1),
#  ('¡ Mon Dieu !', 1),
#  ('Anonadada', 1),
#  ('estar Regina', 1),
#  ('Ricardo Wagner', 1),
#  ('Loca', 1),
#  ('Se detener Regina', 1),
#  ('¡ Cuán', 1),
#  ('¡ Pobrecillas !', 1),
#  ('Jacoba Estrada', 1),
#  ('Juan \n Ramírez', 1),
#  ('Súbitamente', 1),
#  ('Don Fermín Pérez', 1),
#  ('Acerba', 1),
#  ('Infante', 1),
#  ('Adolfo \n concurrir', 1),
#  ('Hablóles', 1),
#  ('¡ Lucidos estar !', 1),
#  ('Buen Paradero _', 1),
#  ('Casino de Torremar', 1),
#  ('Mariposa _', 1),
#  ('Pau', 1),
#  ('Irguió', 1),
#  ('Ya estar', 1),
#  ('Pensar', 1),
#  ('Padezco', 1),
#  ('Medró', 1),
#  ('Iría', 1),
#  ('Saluda', 1),
#  ('Ambos', 1),
#  ('don Adolfo', 1),
#  ('Mirábale', 1),
#  ('También Carlos', 1),
#  ('Cautivo', 1),
#  ('Estalla', 1),
#  ('Velasco--', 1),
#  ('Dos', 1),
#  ('Vuelve', 1),
#  ('Meditando', 1),
#  ('Olvidando', 1),
#  ('Hay', 1),
#  ('Aspada', 1),
#  ('Sentíase Velasquín', 1),
#  ('San Antonio', 1),
#  ('Quiere Regina', 1),
#  ('Quédanse', 1),
#  ('Rafael \n Marín', 1),
#  ('Ana María \n Ramírez', 1),
#  ('Mocero', 1),
#  ('Ante', 1),
#  ('Casino', 1),
#  ('Rhin', 1),
#  ('Siguiendo', 1),
#  ('Señora', 1),
#  ('Débiles', 1),
#  ('Adolfo . Apenas', 1),
#  ('San Simón', 1),
#  ('Silbaron', 1),
#  ('Bellosguardo', 1),
#  ('Pensando', 1),
#  ('Era que', 1),
#  ('Diligente', 1),
#  ('Aun', 1),
#  ('Andando el', 1),
#  ('Reminiscencias', 1),
#  ('¡ Mire', 1),
#  ('Cambiando', 1),
#  ('Carlota--', 1),
#  ('Guarda Velasco', 1),
#  ('Se vestir Regina', 1),
#  ('D. Fermín Pérez', 1),
#  ('Entre', 1),
#  ('Manuel \n Velasco', 1),
#  ('Huye', 1),
#  ('Reina_.', 1),
#  ('Certera', 1),
#  ('Podrá', 1),
#  ('Retiróse', 1),
#  ('El renombre de don Juan', 1),
#  ('Tórnase', 1)]

# %% [markdown]
# Los modelos utilizados para taggear las 'named entities' son modelos estadisticos y la clasificación que realizan
# dependen de los ejemplos con los que fueron entrenados. Esto puede conducir a errores como los que vemos en la lista
# anterior.
#
# También podemos ver que hay palabras que seguramente se estan refiriendo a una persona y probablemente el modelo
# piense que es una persona por el contexto en el cual esta siendo utilizada.
#
# Si tenemos que hacer una primer predicción de quienes son los personajes principales diriamos que, por diferencia de  frecuencia:
#
# Los principales son: Regina, Carlota y Carlos
# Seguidos de Ana María, Adolgo y Manuel.

# %% [markdown]
# ### Intentaremos buscar si existe algún otro personaje principal que los modelos hayan pasado por alto

# %%
places = Counter()

for nam_ent in proc_text.ents:
    if nam_ent.label_ == 'LOC':
        places[nam_ent.lemma_] += 1

places.most_common()
# Out:
# [('', 887),
#  ('Regina', 141),
#  ('Alcántara', 41),
#  ('Torremar', 32),
#  ('Eugenia', 24),
#  ('Ramírez', 22),
#  ('¡', 14),
#  ('Dolores', 9),
#  ('Alcoy', 8),
#  ('Madrid', 7),
#  ('Carlitos', 6),
#  ('Qué', 6),
#  ('Después', 5),
#  ('¡ Qué', 4),
#  ('Bernaldo', 4),
#  ('Europa', 4),
#  ('Spa', 4),
#  ('Heredia', 4),
#  ('Mercedes', 4),
#  ('Sí', 4),
#  ('Andes', 4),
#  ('¡ Si', 4),
#  ('VII', 3),
#  ('Francia', 3),
#  ('Están', 3),
#  ('Pilcomayo', 3),
#  ('A', 3),
#  ('Amaba', 3),
#  ('Intrusa', 3),
#  ('Rhin', 3),
#  ('Tlaloc', 3),
#  ('La', 3),
#  ('Arfeo', 2),
#  ('Selva Negra', 2),
#  ('Sintióse', 2),
#  ('San Martín', 2),
#  ('IV', 2),
#  ('Plata', 2),
#  ('América', 2),
#  ('Santander', 2),
#  ('Plaza Mayor', 2),
#  ('Pues', 2),
#  ('Quedó', 2),
#  ('Parecía', 2),
#  ('Van', 2),
#  ('Fermín', 2),
#  ('Cómo', 2),
#  ('Vigo', 2),
#  ('Miraba', 2),
#  ('Argentina', 2),
#  ('Allí', 2),
#  ('Cuba', 2),
#  ('Tengo', 2),
#  ('Silvia', 2),
#  ('Florencia', 2),
#  ('Ibarrola', 2),
#  ('Roma', 2),
#  ('Torpemente', 2),
#  ('No', 2),
#  ('Casino', 2),
#  ('Gran Chaco', 2),
#  ('Bebe', 2),
#  ('Busca', 2),
#  ('Mayo', 2),
#  ('Quería', 2),
#  ('¡ Con', 2),
#  ('Quién', 2),
#  ('Galicia', 2),
#  ('Marañón', 2),
#  ('Italia', 2),
#  ('San Simón', 2),
#  ('isla Bella', 2),
#  ('Porque', 2),
#  ('Regina de Alcántara', 2),
#  ('Vesubio', 2),
#  ('Estás', 1),
#  ('Regina de', 1),
#  ('¡ Pícalo', 1),
#  ('Atravesaba', 1),
#  ('América Central', 1),
#  ('Sicilia', 1),
#  ('¡ DÍA', 1),
#  ('Impresionable', 1),
#  ('Ecos', 1),
#  ('¡ Oh', 1),
#  ('María', 1),
#  ('El Plata', 1),
#  ('Cuando', 1),
#  ('Egipto', 1),
#  ('Montaba', 1),
#  ('¡ Un', 1),
#  ('Al', 1),
#  ('Tropecé', 1),
#  ('Pegada', 1),
#  ('Benavente', 1),
#  ('Mi', 1),
#  ('callar Real', 1),
#  ('¡ Ibarrola', 1),
#  ('Aquellas', 1),
#  ('cabo de Torremar', 1),
#  ('Inapetente', 1),
#  ('V', 1),
#  ('Asturias', 1),
#  ('Acarició', 1),
#  ('Acuérdate de Spa', 1),
#  ('Noroeste', 1),
#  ('Los', 1),
#  ('¡ Convertirse', 1),
#  ('Ibase', 1),
#  ('Cosen', 1),
#  ('Pacífico', 1),
#  ('Sacude', 1),
#  ('Prometo', 1),
#  ('Diciembre', 1),
#  ('Carrara', 1),
#  ('Hasta Eugenia', 1),
#  ('VIII', 1),
#  ('AMOR.--¡AH DE LA RIBERA !', 1),
#  ('Ramírez \n cubrir', 1),
#  ('Alta', 1),
#  ('Blanqueaban', 1),
#  ('Apostábase', 1),
#  ('Niño', 1),
#  ('¡ Magníficos', 1),
#  ('Río de Janeiro', 1),
#  ('lo Segadora', 1),
#  ('Dormías', 1),
#  ('Madre_', 1),
#  ('Ruan', 1),
#  ('¡ Lo jurar', 1),
#  ('Sintió', 1),
#  ('Bajos \n Pirineos', 1),
#  ('Oye', 1),
#  ('París', 1),
#  ('Adiós', 1),
#  ('Murmura', 1),
#  ('Corre', 1),
#  ('Cansada', 1),
#  ('Africa', 1),
#  ('¡ Mienten', 1),
#  ('Ingeniosa', 1),
#  ('Tienes', 1),
#  ('Siente', 1),
#  ('Curiosa', 1),
#  ('Filomena', 1),
#  ('Viudo', 1),
#  ('¡ Jesús', 1),
#  ('He', 1),
#  ('ISLA DE LAS ROSAS PÁLIDAS', 1),
#  ('vallar del Chota', 1),
#  ('Avecindados', 1),
#  ('¡ Perdón', 1),
#  ('Uruguay', 1),
#  ('Con', 1),
#  ('Hundía', 1),
#  ('Hubo', 1),
#  ('Tánger', 1),
#  ('Vió', 1),
#  ('VENTABA el Noroeste', 1),
#  ('Pero', 1),
#  ('Ríos', 1),
#  ('Secreto', 1),
#  ('Cree', 1),
#  ('Volvió', 1),
#  ('¡ Nada ! ... ¡ Nada !', 1),
#  ('Cantabria', 1),
#  ('V \n\n AMOR CON', 1),
#  ('Muchas tarde Regina', 1),
#  ('Señoría', 1),
#  ('Rueda', 1),
#  ('Atraviesa \n valle', 1),
#  ('Cruzan', 1),
#  ('Desea', 1),
#  ('Avon', 1),
#  ('Enamorada ?', 1),
#  ('Virgen del Carmen', 1),
#  ('Madre', 1),
#  ('Irresoluta', 1),
#  ('Nuestras', 1),
#  ('Sur', 1),
#  ('San \n Cristóbal de lo Habana', 1),
#  ('Splügen', 1),
#  ('Óyese', 1),
#  ('Acaso el Magdalena ?', 1),
#  ('Vimos', 1),
#  ('Puso', 1),
#  ('¡ Uno', 1),
#  ('Misericordia', 1),
#  ('¡ Para', 1),
#  ('¡ Soledad', 1),
#  ('Alejada', 1),
#  ('Mudamente', 1),
#  ('¡ Eramos', 1),
#  ('Medicina', 1),
#  ('Todos', 1),
#  ('Derroché mi \n juventud', 1),
#  ('LAZARETO DE SAN SIMÓN', 1),
#  ('Avara', 1),
#  ('Alemania', 1),
#  ('Canadá', 1),
#  ('Salió', 1),
#  ('Verona', 1),
#  ('Supones', 1),
#  ('Asia', 1),
#  ('Rosario', 1),
#  ('Puesta', 1),
#  ('¡ Ha', 1),
#  ('NUEVA!--HISTORIA', 1),
#  ('¡ Nunca', 1),
#  ('¡ Dímelo', 1),
#  ('Clavada', 1),
#  ('¡ Mira', 1),
#  ('Enfrente', 1),
#  ('Ordóñez', 1),
#  ('Danubio', 1),
#  ('Regia', 1),
#  ('También \n Carlitos', 1),
#  ('Genia', 1),
#  ('Ayuntamiento', 1),
#  ('Lazareto', 1),
#  ('Contemplábala', 1),
#  ('Retroceden', 1),
#  ('Devoto', 1),
#  ('Hablas', 1),
#  ('Hallábanse', 1),
#  ('Sabes', 1),
#  ('Suele', 1),
#  ('Conturbada', 1),
#  ('Norte', 1),
#  ('Oceanía', 1),
#  ('Sordamente', 1),
#  ('¡ Nunca ! ... \n Por vuestro amor llevar lo cruz de este suplicio en secretar espantoso ... \n Ana María',
#   1),
#  ('Cuento', 1),
#  ('Venus', 1),
#  ('Logró', 1),
#  ('Levantarían', 1),
#  ('Siento', 1),
#  ('Victoriano', 1),
#  ('Exaltados', 1),
#  ('Contempló', 1),
#  ('Chile', 1),
#  ('Tomaba', 1),
#  ('montar Rosa', 1),
#  ('Virgen ?', 1),
#  ('¡ Amar', 1),
#  ('Estraduca', 1),
#  ('lo Elida', 1),
#  ('Plaza', 1),
#  ('¡ Ya', 1),
#  ('Heredias', 1),
#  ('Inglaterra', 1),
#  ('Gabriel', 1),
#  ('El caminar', 1),
#  ('Resbalan', 1),
#  ('¡ Y', 1),
#  ('¡ Sí querer _', 1),
#  ('Llevó', 1),
#  ('Helesponto', 1),
#  ('Apareja', 1),
#  ('Cuál', 1),
#  ('Estambul', 1),
#  ('Trianón', 1),
#  ('península de Escandinavia', 1),
#  ('Lanzada', 1),
#  ('Monte Rosa', 1),
#  ('Soldado', 1),
#  ('Nilo', 1),
#  ('¡ Hijo', 1),
#  ('Mármara', 1),
#  ('Pasados', 1),
#  ('Creyó \n lo', 1),
#  ('Dióse', 1),
#  ('Cuanto', 1),
#  ('Velasquín', 1),
#  ('Cayó', 1),
#  ('¡ Vámonos', 1),
#  ('Anoche', 1),
#  ('Incas', 1),
#  ('Dux', 1),
#  ('Atenas', 1),
#  ('BOHEMIA', 1),
#  ('Regresaba', 1),
#  ('Brotaba', 1),
#  ('Sólo', 1),
#  ('¡ Mi', 1),
#  ('Le', 1),
#  ('VI', 1),
#  ('Torre de lo Doncella', 1),
#  ('Allá', 1),
#  ('Eleusis', 1),
#  ('Sucedió', 1),
#  ('Muchas', 1),
#  ('Santiago de Chile', 1),
#  ('Contribuyó', 1),
#  ('Meció', 1),
#  ('I', 1),
#  ('Sino', 1),
#  ('entrañar de Regina', 1),
#  ('Levanta', 1),
#  ('Estos', 1),
#  ('Supongo', 1),
#  ('Ultramar', 1),
#  ('¡ Yo', 1),
#  ('Feto', 1),
#  ('Escribir \n libro', 1),
#  ('EUGENIA', 1),
#  ('Consulta', 1),
#  ('Noruega', 1),
#  ('Encendiósele', 1),
#  ('Presa', 1),
#  ('TRIANON».--PROSIGUE', 1),
#  ('lo Alpes', 1),
#  ('Condestables', 1),
#  ('Caía', 1),
#  ('Inicia', 1),
#  ('Rodaba', 1),
#  ('Había', 1),
#  ('La de Alcántara', 1),
#  ('Ansiaba', 1),
#  ('Quiere', 1),
#  ('Escucha ... Escucha', 1),
#  ('RETRATOS', 1),
#  ('Brasil', 1),
#  ('Tívoli', 1),
#  ('¡ Tiene', 1),
#  ('Normandía', 1),
#  ('¡ Pobre', 1),
#  ('Unidos', 1),
#  ('Usted', 1),
#  ('Los \n recio perfilar del navío', 1),
#  ('Seré', 1),
#  ('Educóse', 1),
#  ('AGONIZA', 1),
#  ('Algunos', 1),
#  ('Suspiros', 1),
#  ('lo Selva', 1),
#  ('Quizá', 1),
#  ('¡ No', 1),
#  ('También', 1),
#  ('Niño Dios', 1),
#  ('Etna', 1),
#  ('Continente', 1),
#  ('Velasco', 1),
#  ('Te', 1),
#  ('Tácitamente', 1),
#  ('Estoy', 1),
#  ('Sintiéndose', 1),
#  ('Quiero', 1),
#  ('Corazón', 1),
#  ('rúa Mayor', 1),
#  ('Austral', 1),
#  ('Acércanse', 1),
#  ('TORREMAR', 1),
#  ('La \n reinar del Adriático', 1),
#  ('Regina de \n Alcántara', 1)]

# %% [markdown]
# Aquí aparece el personaje de Regina nuevamente, que creemos es el personaje principal de la historia. Una posibilidad
# por la cual haya sido clasificada como un lugar es que durante el libro es nombrada en reiteradas ocasiones como
# Regina de Alcántara. Siendo Alcántara un lugar (municipio de españa)

# %% [markdown]
# ### Dado que Regina y Carlota parecen ser los dos personajes principales, ¿En cuantas oraciones aparecen juntas? ¿En cuantas aparecen cada una por separado?

# %%
reg_car_sent = [sent for sent in proc_text.sents if ('Regina' in sent.string and 'Carlota' in sent.string)]
reg_sent = [sent for sent in proc_text.sents if 'Regina' in sent.string]
car_sent = [sent for sent in proc_text.sents if 'Carlota' in sent.string]
total_sent = [sent for sent in proc_text.sents]

print("Regina y Carlota aparecen juntas en {0} de {1} oraciones".format(len(reg_car_sent), len(total_sent)))
print("Regina aparece en {0} de {1} oraciones".format(len(reg_sent), len(total_sent)))
print("Carlota aparece en {0} de {1} oraciones".format(len(car_sent), len(total_sent)))
# Out:
# Regina y Carlota aparecen juntas en 14 de 2764 oraciones
# Regina aparece en 405 de 2764 oraciones
# Carlota aparece en 96 de 2764 oraciones

# %%
# Observando el texto se puede ver que por algún motivo la versión de proyecto gutemberg se encuentra mal escrita con 
# lo cual se dificultando mucho la tarea de los modelos y por ende de todos los analisis posibles.
# por ejemplo: Veamos las ultimas 3 oraciones donde regina y carlota aparecen juntas

reg_car_sent[-3:]
# Out:
# [La sublimidad
#  de Carlota, liberta de su cruel esclavitud por el amor, y esclava, por
#  el amor mismo, en un convento, resultábale á Regina tan misteriosa y
#  vaga como el impulso de «la novia de Rolando», cautiva de sagrada
#  clausura por creer á su amante víctima de la guerra., El
#  matrimonio, en apariencia semejante al que la dama rubia conmemora en
#  cruel aniversario, sabe ella que es en el fondo muy distinto del suyo, y
#  admira con humildad sus nobles fundamentos: quiere Carlota partir con su
#  hijo para consagrarse á levantar el vuelo de aquel mustio corazón, en
#  saludable mudanza de horizontes; pero antes paga sus deudas de gratitud
#  á la ilustre familia de Velasco y ofrece á su hija la ventura, con
#  suprema generosidad, empujándola hacia el palacio del valle, donde
#  siembre sonrisas y consolaciones sobre la memoria de Velasquín;
#  consiente Manuel, devoto cumplidor de sus palabras y preclaro artífice
#  de bellas obras, y doña Mercedes abre sus brazos temblorosos para
#  abrazarse al «hada del _Robledo_» como á un providencial refugio...
#  Peregrinos y claros le parecen á Regina estos propósitos que apenas
#  trascienden, ocultos con humilde cautela, bajo la capa misteriosa del
#  destino.,
#
#  Entra don Fermín con aire solemne, saluda y soliloquia:
#
#  --Vamos á ver... Vamos á ver...
#
#  Quédase mirando á Regina, que se ha puesto muy pálida; la pulsa, y
#  acariciando aquella mano temblorosa con paternal solicitud, trata de
#  entablar conversación para distraer á su enferma; refiere que el
#  temporal le ha impedido venir aquellos días; habla del reciente cambio
#  de temperatura, y cuenta que ha estado en la estación á despedir á
#  Carlota y á su hijo.]

# %% [markdown]
# **Aquí podemos ver que se hace abuso del recurso '...' y que la puntuación en general no se encuentra bien utilizada.**
